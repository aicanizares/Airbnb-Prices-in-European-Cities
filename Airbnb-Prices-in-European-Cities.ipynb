# %%
# !pip install pandas

# %%
import pandas as pd

# %%
# Set naming conventions for the 20 different datasets
# wd: weekdays
# we: weekends

# ams: Amsterdam
# ath: Athens
# bcn: Barcelona
# ber: Berlin
# bud: Budapest
# lis: Lisbon
# lon: London
# par: Paris
# rom: Rome
# vie: Vienna

# %%
# wd: weekdays
# ams: Amsterdam
df_ams_wd = pd.read_csv("https://raw.githubusercontent.com/aicanizares/Airbnb-Prices-in-European-Cities/refs/heads/main/amsterdam_weekdays.csv")

# %%
df_ams_wd.head(5)
# Out:
#    Unnamed: 0     realSum     room_type  room_shared  room_private  \
# 0           0  194.033698  Private room        False          True
# 1           1  344.245776  Private room        False          True
# 2           2  264.101422  Private room        False          True
# 3           3  433.529398  Private room        False          True
# 4           4  485.552926  Private room        False          True
#
#    person_capacity  host_is_superhost  multi  biz  cleanliness_rating  \
# 0              2.0              False      1    0                10.0
# 1              4.0              False      0    0                 8.0
# 2              2.0              False      0    1                 9.0
# 3              4.0              False      0    1                 9.0
# 4              2.0               True      0    0                10.0
#
#    guest_satisfaction_overall  bedrooms      dist  metro_dist  attr_index  \
# ...

# %%
print(df_ams_wd.isnull().sum())
# Out:
# Unnamed: 0                    0
# realSum                       0
# room_type                     0
# room_shared                   0
# room_private                  0
# person_capacity               0
# host_is_superhost             0
# multi                         0
# biz                           0
# cleanliness_rating            0
# guest_satisfaction_overall    0
# bedrooms                      0
# dist                          0
# metro_dist                    0
# attr_index                    0
# attr_index_norm               0
# rest_index                    0
# rest_index_norm               0
# lng                           0
# lat                           0
# dtype: int64

# %%
# Drop "unnamed" column
# df_a_wd = df_a_wd.drop(columns=['Unnamed: 0'])
# Instead of dropping 1 column in 20 datasets, drop the column once after concatenation.
# NOT DONE

# %%
df_ams_wd.head(5)
# Out:
#    Unnamed: 0     realSum     room_type  room_shared  room_private  \
# 0           0  194.033698  Private room        False          True
# 1           1  344.245776  Private room        False          True
# 2           2  264.101422  Private room        False          True
# 3           3  433.529398  Private room        False          True
# 4           4  485.552926  Private room        False          True
#
#    person_capacity  host_is_superhost  multi  biz  cleanliness_rating  ...  \
# 0              2.0              False      1    0                10.0  ...
# 1              4.0              False      0    0                 8.0  ...
# 2              2.0              False      0    1                 9.0  ...
# 3              4.0              False      0    1                 9.0  ...
# 4              2.0               True      0    0                10.0  ...
#
#        dist  metro_dist  attr_index  attr_index_norm  rest_index  \
# ...

# %%
# Add the column "day_type" and fill all rows with the value "weekdays"
df_ams_wd["day_type"] = "weekdays"

# %%
df_ams_wd.head(5)
# Out:
#    Unnamed: 0     realSum     room_type  room_shared  room_private  \
# 0           0  194.033698  Private room        False          True
# 1           1  344.245776  Private room        False          True
# 2           2  264.101422  Private room        False          True
# 3           3  433.529398  Private room        False          True
# 4           4  485.552926  Private room        False          True
#
#    person_capacity  host_is_superhost  multi  biz  cleanliness_rating  ...  \
# 0              2.0              False      1    0                10.0  ...
# 1              4.0              False      0    0                 8.0  ...
# 2              2.0              False      0    1                 9.0  ...
# 3              4.0              False      0    1                 9.0  ...
# 4              2.0               True      0    0                10.0  ...
#
#    bedrooms      dist  metro_dist  attr_index  attr_index_norm  rest_index  \
# ...

# %%
# Add the column "city" and fill all rows with the value "Amsterdam"
df_ams_wd["city"] = "Amsterdam"

# %%
df_ams_wd.head(5)
# Out:
#    Unnamed: 0     realSum     room_type  room_shared  room_private  \
# 0           0  194.033698  Private room        False          True
# 1           1  344.245776  Private room        False          True
# 2           2  264.101422  Private room        False          True
# 3           3  433.529398  Private room        False          True
# 4           4  485.552926  Private room        False          True
#
#    person_capacity  host_is_superhost  multi  biz  cleanliness_rating  ...  \
# 0              2.0              False      1    0                10.0  ...
# 1              4.0              False      0    0                 8.0  ...
# 2              2.0              False      0    1                 9.0  ...
# 3              4.0              False      0    1                 9.0  ...
# 4              2.0               True      0    0                10.0  ...
#
#        dist  metro_dist  attr_index  attr_index_norm  rest_index  \
# ...

# %%
# df_ams_we
df_ams_we = pd.read_csv("https://raw.githubusercontent.com/aicanizares/Airbnb-Prices-in-European-Cities/refs/heads/main/amsterdam_weekends.csv")

# %%
# Add the column "day_type" and fill all rows with the value "weekends"
df_ams_we["day_type"] = "weekends"

# %%
# Add the column "city" and fill all rows with the value "Amsterdam"
df_ams_we["city"] = "Amsterdam"

# %%
df_ams_we.head(5)
# Out:
#    Unnamed: 0      realSum        room_type  room_shared  room_private  \
# 0           0   319.640053     Private room        False          True
# 1           1   347.995219     Private room        False          True
# 2           2   482.975183     Private room        False          True
# 3           3   485.552926     Private room        False          True
# 4           4  2771.541724  Entire home/apt        False         False
#
#    person_capacity  host_is_superhost  multi  biz  cleanliness_rating  ...  \
# 0              2.0              False      0    1                 9.0  ...
# 1              2.0              False      0    1                 9.0  ...
# 2              4.0              False      0    1                 9.0  ...
# 3              2.0               True      0    0                10.0  ...
# 4              4.0               True      0    0                10.0  ...
#
#        dist  metro_dist  attr_index  attr_index_norm  rest_index  \
# ...

# %%
# Concatenate df_ams_wd & df_ams_we
df_ams = pd.concat([df_ams_wd, df_ams_we], ignore_index=True)

# %%
df_ams.head(5)
# Out:
#    Unnamed: 0     realSum     room_type  room_shared  room_private  \
# 0           0  194.033698  Private room        False          True
# 1           1  344.245776  Private room        False          True
# 2           2  264.101422  Private room        False          True
# 3           3  433.529398  Private room        False          True
# 4           4  485.552926  Private room        False          True
#
#    person_capacity  host_is_superhost  multi  biz  cleanliness_rating  ...  \
# 0              2.0              False      1    0                10.0  ...
# 1              4.0              False      0    0                 8.0  ...
# 2              2.0              False      0    1                 9.0  ...
# 3              4.0              False      0    1                 9.0  ...
# 4              2.0               True      0    0                10.0  ...
#
#        dist  metro_dist  attr_index  attr_index_norm  rest_index  \
# ...

# %%
df_ams.shape
# Out:
# (2080, 22)

# %%
# df_ath_wd
df_ath_wd = pd.read_csv("https://raw.githubusercontent.com/aicanizares/Airbnb-Prices-in-European-Cities/refs/heads/main/athens_weekdays.csv")
